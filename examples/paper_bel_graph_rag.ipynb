# %% [markdown]
# # BEL Graph RAG Example for paper usecases

# %%
# %pip install ndex2 langchain

# %%
# %pip install texttoknowledgegraph==0.3.7
# Out:
# WARNING: Ignoring invalid distribution ~ympy (/opt/homebrew/anaconda3/lib/python3.11/site-packages)
# Requirement already satisfied: texttoknowledgegraph==0.3.7 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (0.3.7)
# Requirement already satisfied: langchain==0.3.25 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (0.3.25)
# Requirement already satisfied: langchain_core==0.3.60 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (0.3.60)
# Requirement already satisfied: langchain_openai==0.3.17 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (0.3.17)
# Requirement already satisfied: lxml==5.2.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (5.2.1)
# Requirement already satisfied: ndex2<4.0.0,>=3.8.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (3.10.0)
# Requirement already satisfied: pandas in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (2.2.2)
# Requirement already satisfied: openai==1.79.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (1.79.0)
# Requirement already satisfied: pydantic==2.11.4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (2.11.4)
# Requirement already satisfied: pytest==7.4.4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (7.4.4)
# Requirement already satisfied: python-dotenv==1.1.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (1.1.0)
# Requirement already satisfied: Requests==2.32.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (2.32.3)
# Requirement already satisfied: gilda==1.4.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (1.4.0)
# Requirement already satisfied: markitdown[all] in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (0.1.1)
# Requirement already satisfied: nltk in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from texttoknowledgegraph==0.3.7) (3.9.1)
# Requirement already satisfied: regex in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gilda==1.4.0->texttoknowledgegraph==0.3.7) (2024.11.6)
# Requirement already satisfied: boto3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gilda==1.4.0->texttoknowledgegraph==0.3.7) (1.38.28)
# Requirement already satisfied: adeft in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gilda==1.4.0->texttoknowledgegraph==0.3.7) (0.12.3)
# Requirement already satisfied: flask<4.0,>=3.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gilda==1.4.0->texttoknowledgegraph==0.3.7) (3.1.1)
# Requirement already satisfied: flask-restx>=1.3.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gilda==1.4.0->texttoknowledgegraph==0.3.7) (1.3.0)
# Requirement already satisfied: pystow>=0.1.10 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gilda==1.4.0->texttoknowledgegraph==0.3.7) (0.7.0)
# Requirement already satisfied: unidecode in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gilda==1.4.0->texttoknowledgegraph==0.3.7) (1.4.0)
# Requirement already satisfied: werkzeug in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gilda==1.4.0->texttoknowledgegraph==0.3.7) (3.1.3)
# Requirement already satisfied: scikit-learn<1.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gilda==1.4.0->texttoknowledgegraph==0.3.7) (1.4.2)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain==0.3.25->texttoknowledgegraph==0.3.7) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain==0.3.25->texttoknowledgegraph==0.3.7) (0.3.44)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain==0.3.25->texttoknowledgegraph==0.3.7) (2.0.41)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain==0.3.25->texttoknowledgegraph==0.3.7) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain_core==0.3.60->texttoknowledgegraph==0.3.7) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain_core==0.3.60->texttoknowledgegraph==0.3.7) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain_core==0.3.60->texttoknowledgegraph==0.3.7) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain_core==0.3.60->texttoknowledgegraph==0.3.7) (4.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pydantic==2.11.4->texttoknowledgegraph==0.3.7) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pydantic==2.11.4->texttoknowledgegraph==0.3.7) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pydantic==2.11.4->texttoknowledgegraph==0.3.7) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from Requests==2.32.3->texttoknowledgegraph==0.3.7) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from Requests==2.32.3->texttoknowledgegraph==0.3.7) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from Requests==2.32.3->texttoknowledgegraph==0.3.7) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from Requests==2.32.3->texttoknowledgegraph==0.3.7) (2025.4.26)
# Requirement already satisfied: tiktoken<1,>=0.7 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain_openai==0.3.17->texttoknowledgegraph==0.3.7) (0.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from openai==1.79.0->texttoknowledgegraph==0.3.7) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from openai==1.79.0->texttoknowledgegraph==0.3.7) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from openai==1.79.0->texttoknowledgegraph==0.3.7) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from openai==1.79.0->texttoknowledgegraph==0.3.7) (0.10.0)
# Requirement already satisfied: sniffio in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from openai==1.79.0->texttoknowledgegraph==0.3.7) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from openai==1.79.0->texttoknowledgegraph==0.3.7) (4.67.1)
# Requirement already satisfied: iniconfig in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pytest==7.4.4->texttoknowledgegraph==0.3.7) (2.1.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pytest==7.4.4->texttoknowledgegraph==0.3.7) (1.6.0)
# Requirement already satisfied: blinker>=1.9.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from flask<4.0,>=3.0->gilda==1.4.0->texttoknowledgegraph==0.3.7) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from flask<4.0,>=3.0->gilda==1.4.0->texttoknowledgegraph==0.3.7) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from flask<4.0,>=3.0->gilda==1.4.0->texttoknowledgegraph==0.3.7) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from flask<4.0,>=3.0->gilda==1.4.0->texttoknowledgegraph==0.3.7) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from flask<4.0,>=3.0->gilda==1.4.0->texttoknowledgegraph==0.3.7) (3.0.2)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai==1.79.0->texttoknowledgegraph==0.3.7) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.79.0->texttoknowledgegraph==0.3.7) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain_core==0.3.60->texttoknowledgegraph==0.3.7) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.25->texttoknowledgegraph==0.3.7) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.25->texttoknowledgegraph==0.3.7) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.25->texttoknowledgegraph==0.3.7) (0.23.0)
# Requirement already satisfied: six in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ndex2<4.0.0,>=3.8.0->texttoknowledgegraph==0.3.7) (1.17.0)
# Requirement already satisfied: ijson in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ndex2<4.0.0,>=3.8.0->texttoknowledgegraph==0.3.7) (3.4.0)
# Requirement already satisfied: networkx in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ndex2<4.0.0,>=3.8.0->texttoknowledgegraph==0.3.7) (3.5)
# Requirement already satisfied: numpy in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ndex2<4.0.0,>=3.8.0->texttoknowledgegraph==0.3.7) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit-learn<1.5->gilda==1.4.0->texttoknowledgegraph==0.3.7) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit-learn<1.5->gilda==1.4.0->texttoknowledgegraph==0.3.7) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit-learn<1.5->gilda==1.4.0->texttoknowledgegraph==0.3.7) (3.6.0)
# Requirement already satisfied: aniso8601>=0.82 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from flask-restx>=1.3.0->gilda==1.4.0->texttoknowledgegraph==0.3.7) (10.0.1)
# Requirement already satisfied: jsonschema in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from flask-restx>=1.3.0->gilda==1.4.0->texttoknowledgegraph==0.3.7) (4.24.0)
# Requirement already satisfied: pytz in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from flask-restx>=1.3.0->gilda==1.4.0->texttoknowledgegraph==0.3.7) (2025.2)
# Requirement already satisfied: importlib-resources in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from flask-restx>=1.3.0->gilda==1.4.0->texttoknowledgegraph==0.3.7) (6.5.2)
# Requirement already satisfied: appdirs in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from adeft->gilda==1.4.0->texttoknowledgegraph==0.3.7) (1.4.4)
# Requirement already satisfied: botocore<1.39.0,>=1.38.28 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from boto3->gilda==1.4.0->texttoknowledgegraph==0.3.7) (1.38.28)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from boto3->gilda==1.4.0->texttoknowledgegraph==0.3.7) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from boto3->gilda==1.4.0->texttoknowledgegraph==0.3.7) (0.13.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from botocore<1.39.0,>=1.38.28->boto3->gilda==1.4.0->texttoknowledgegraph==0.3.7) (2.9.0.post0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from jsonschema->flask-restx>=1.3.0->gilda==1.4.0->texttoknowledgegraph==0.3.7) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from jsonschema->flask-restx>=1.3.0->gilda==1.4.0->texttoknowledgegraph==0.3.7) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from jsonschema->flask-restx>=1.3.0->gilda==1.4.0->texttoknowledgegraph==0.3.7) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from jsonschema->flask-restx>=1.3.0->gilda==1.4.0->texttoknowledgegraph==0.3.7) (0.25.1)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (4.13.4)
# Requirement already satisfied: magika~=0.6.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (0.6.2)
# Requirement already satisfied: markdownify in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (1.1.0)
# Requirement already satisfied: azure-ai-documentintelligence in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (1.0.0)
# Requirement already satisfied: azure-identity in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (1.20.0)
# Requirement already satisfied: mammoth in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (1.9.0)
# Requirement already satisfied: olefile in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (0.47)
# Requirement already satisfied: openpyxl in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (3.1.5)
# Requirement already satisfied: pdfminer-six in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (20240706)
# Requirement already satisfied: pydub in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (0.25.1)
# Requirement already satisfied: python-pptx in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (1.0.2)
# Requirement already satisfied: speechrecognition in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (3.14.1)
# Requirement already satisfied: xlrd in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (2.0.1)
# Requirement already satisfied: youtube-transcript-api~=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markitdown[all]->texttoknowledgegraph==0.3.7) (1.0.3)
# Requirement already satisfied: onnxruntime>=1.17.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from magika~=0.6.1->markitdown[all]->texttoknowledgegraph==0.3.7) (1.19.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from youtube-transcript-api~=1.0.0->markitdown[all]->texttoknowledgegraph==0.3.7) (0.7.1)
# Requirement already satisfied: coloredlogs in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]->texttoknowledgegraph==0.3.7) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]->texttoknowledgegraph==0.3.7) (25.2.10)
# Requirement already satisfied: protobuf in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]->texttoknowledgegraph==0.3.7) (6.31.1)
# Requirement already satisfied: sympy in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]->texttoknowledgegraph==0.3.7) (1.11.1)
# Requirement already satisfied: isodate>=0.6.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from azure-ai-documentintelligence->markitdown[all]->texttoknowledgegraph==0.3.7) (0.6.1)
# Requirement already satisfied: azure-core>=1.30.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from azure-ai-documentintelligence->markitdown[all]->texttoknowledgegraph==0.3.7) (1.32.0)
# Requirement already satisfied: cryptography>=2.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from azure-identity->markitdown[all]->texttoknowledgegraph==0.3.7) (42.0.5)
# Requirement already satisfied: msal>=1.30.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from azure-identity->markitdown[all]->texttoknowledgegraph==0.3.7) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from azure-identity->markitdown[all]->texttoknowledgegraph==0.3.7) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity->markitdown[all]->texttoknowledgegraph==0.3.7) (1.16.0)
# Requirement already satisfied: pycparser in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity->markitdown[all]->texttoknowledgegraph==0.3.7) (2.21)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->markitdown[all]->texttoknowledgegraph==0.3.7) (2.8.0)
# Requirement already satisfied: portalocker<3,>=1.4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from msal-extensions>=1.2.0->azure-identity->markitdown[all]->texttoknowledgegraph==0.3.7) (2.10.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->markitdown[all]->texttoknowledgegraph==0.3.7) (2.7)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]->texttoknowledgegraph==0.3.7) (10.0)
# Requirement already satisfied: cobble<0.2,>=0.1.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from mammoth->markitdown[all]->texttoknowledgegraph==0.3.7) (0.1.4)
# Requirement already satisfied: et-xmlfile in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from openpyxl->markitdown[all]->texttoknowledgegraph==0.3.7) (1.1.0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas->texttoknowledgegraph==0.3.7) (2025.2)
# Requirement already satisfied: Pillow>=3.3.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from python-pptx->markitdown[all]->texttoknowledgegraph==0.3.7) (10.4.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from python-pptx->markitdown[all]->texttoknowledgegraph==0.3.7) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from sympy->onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]->texttoknowledgegraph==0.3.7) (1.3.0)
# WARNING: Ignoring invalid distribution ~ympy (/opt/homebrew/anaconda3/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/opt/homebrew/anaconda3/lib/python3.11/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
from typing import List, Dict, Any
from pathlib import Path
import sys
from ndex2 import Ndex2
import ndex2
from ndex2.cx2 import CX2Network
from dotenv import load_dotenv
from ndex2.cx2 import RawCX2NetworkFactory
load_dotenv()



# Get NDEx account and password from environment variables
OPENAI_API_KEY   = os.getenv("OPENAI_API_KEY")
NDEX_ACCOUNT     = os.getenv("NDEX_ACCOUNT")
NDEX_PASSWORD    = os.getenv("NDEX_PASSWORD")
assert all([OPENAI_API_KEY, NDEX_ACCOUNT, NDEX_PASSWORD]), "Missing creds"

# Connect to NDEx using the provided credentials
ndex_client = Ndex2(username=NDEX_ACCOUNT, password=NDEX_PASSWORD)

# %% [markdown]
# ## Download existing knowledege graph from NDEx

# %%
BASE_KG_UUID = "7a3195e9-4c50-11f0-a218-005056ae3c32"   # put your base KG UUID here
base_cx2 = ndex_client.get_network_as_cx2_stream(BASE_KG_UUID).json()
with open("base_kg.cx2", "w") as f: json.dump(base_cx2, f)

# %% [markdown]
# ## Set up Gene-Set Summary

# %%
# This was genearted by openai 4o-mini by passing two papers as context to it

GENE_SET_SUMMARY = """
Core NAD⁺ Regulatory & TP53 Circuit
SIRT1 ↔ PARP1 competition: Both enzymes consume NAD⁺; NAMPT/NMNAT1 fuel NAD⁺ salvage. PKC-mediated phosphorylation of NMNAT1 fine-tunes local NAD⁺ supply to these antagonistic players.

TP53 integration: PARP1 ADP-ribosylates TP53 upon DNA damage; SIRT1 deacetylates TP53 to modulate its transcriptional activity and cell-fate decisions.

Post-Translational Modification Module
Kinase regulation:

JNK phosphorylates and activates SIRT1.

AMPK phosphorylates PARP1 (enhancing DNA repair) but inhibits SIRT1.

DNA-PK (PRKDC) phosphorylates MDM2, altering TP53 stability.

Ubiquitin/SUMO crosstalk:

MDM2 ubiquitinates TP53 for proteasomal turnover.

SUMO1/3 conjugation on SIRT1 and PARP1 tunes their chromatin-remodeling and co-activator roles.

Chromatin Remodeling & DNA Repair Hub
SIRT1 deacetylation: Removes acetyl marks on H1K26, H3K9/14, H4K16, recruiting TIP60 and MOF to direct DSB repair pathway choice.

PARP1 PARylation: ADP-ribosylates H1 and core histones, loosening chromatin and scaffolding XRCC1, POL β, and LIG III at damage sites.

BRCA1 cooperation: Interacts with TP53 to promote transcription of homologous-recombination genes.

Transcriptional Feedback Loops
TP53 ↔ MDM2: Autoregulatory loop governs TP53 abundance.

E2F1 ↔ SIRT1: E2F1 upregulates SIRT1; SIRT1 deacetylates E2F1, modulating cell-cycle entry.

c-MYC ↔ SIRT1: c-MYC induces SIRT1; SIRT1 deacetylation affects c-MYC stability and transcriptional output.

NF-κB (RELA/p65): PARP1-mediated acetylation boosts p65 activity; SIRT1 deacetylates p65 to restrain inflammatory signaling.

Circadian & Metabolic Integration
CLOCK–BMAL1 → NAMPT: Drives oscillatory NAD⁺ synthesis.

SIRT1 deacetylates BMAL1 and PER2, tuning circadian amplitude.

PARP1 rhythmically PARylates CLOCK to adjust phase shifts under feeding-entrained conditions.
"""

# %%
from openai import OpenAI
from typing import List

# Initialize OpenAI client
client = OpenAI(api_key=OPENAI_API_KEY)

# Step 3: Entity extraction
entity_prompt_template = """
Interpret this text to extract all genes/proteins mentioned and output them as a whitespace-separated list of human gene symbols.
<example>
TP53 AKT1 MTOR
</example>
Only output that list, nothing else.
<text>
{text}
</text>
"""

def query_llm(prompt: str) -> str:
    """
    Query OpenAI's GPT model.
    """
    try:
        completion = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "user", "content": prompt}
            ],
            temperature=0.7,
            max_tokens=1000
        )
        return completion.choices[0].message.content.strip()
    except Exception as e:
        print(f"Error querying OpenAI: {str(e)}")
        return ""

def get_entities(text: str) -> List[str]:
    """
    Extract gene entities from text using LLM.
    """
    prompt = entity_prompt_template.format(text=text)
    response = query_llm(prompt)
    if response:
        return response
    return ""

kg_query_string = get_entities(GENE_SET_SUMMARY)
kg_network_id = BASE_KG_UUID

print(f'Query string to KG in NDEx: {kg_query_string}')

nice_kg_query_network = ndex2.create_nice_cx_from_raw_cx(ndex_client.get_neighborhood(kg_network_id, kg_query_string, search_depth=1))

# convert the network to a string containing BEL statements and supporting evidence
knowledge_graph = ""

for edge_id, edge_obj in nice_kg_query_network.get_edges():
    knowledge_graph += nice_kg_query_network.get_edge_attribute_value(edge_obj, "bel_expression")
    knowledge_graph += "\n"

print("NDEx query done")
# Out:
# Query string to KG in NDEx: TP53 SIRT1 PARP1 NAMPT NMNAT1 PKC JNK AMPK PRKDC MDM2 SUMO1 TIP60 MOF XRCC1 POLB LIG3 BRCA1 E2F1 MYC RELA CLOCK BMAL1 PER2
# NDEx query done

# %%
# Step 4: Critique templates
PROMPT_TEMPLATE = """
You are playing the role of an expert cancer biologist.

TASK:
1. Review the following gene/protein set.
2. Review the following summary of the gene set's function and potential relationship to cancer.
   The summary was produced by an LLM.
3. Provide your critique, including your reasoning about the causal relationships between entities.
4. Provide advice that can be incorporated in the prompt to the LLM to improve its output.
5. Provide additional advice for the LLM as a causal knowledge graph of relevant facts that would help it.

Present one statement per line using BEL format.

Genes: {geneset}

Gene set summary:
{gene_set_summary}

{knowledge_graph}

Output format:
## Genes
<genes>

## Critique:
<critique>

"advice": "<advice_to_llm>",
"causal_relationship_advice_graph": "
 - <BEL_statement> : <evidence_text>
..."
}}
"""

KNOWLEDGE_GRAPH_TEMPLATE = """
Here is information in BEL format that may help you perform your critique.
Be sure to distinguish when you draw on this information vs when you use your own knowledge.

{statements}
"""

# %%
# Step 5: Query the LLM with the gene set and summary without the knowledge graph
prompt = PROMPT_TEMPLATE.format(
    geneset=kg_query_string,
    gene_set_summary = GENE_SET_SUMMARY,
    knowledge_graph=""
)

analysis_no_kg = query_llm(prompt)
print(analysis_no_kg)
# Out:
# ## Genes
# TP53, SIRT1, PARP1, NAMPT, NMNAT1, PKC, JNK, AMPK, PRKDC, MDM2, SUMO1, TIP60, MOF, XRCC1, POLB, LIG3, BRCA1, E2F1, MYC, RELA, CLOCK, BMAL1, PER2
#
# ## Critique:
# Overall, the summary captures several key interactions within the gene/protein set, but there are some inaccuracies and missing details that could lead to misunderstandings regarding the roles of these proteins in cancer biology.
#
# 1. The description of SIRT1 and PARP1 competition for NAD⁺ is correct; however, the context of how this affects cellular processes, particularly in cancer, is not fully explored. SIRT1 and PARP1 have broader roles in DNA repair and metabolism that impact tumorigenesis.
#
# 2. The role of TP53 is somewhat simplified. While PARP1 does ADP-ribosylate TP53, the impact on TP53's tumor suppressor functions, including apoptosis and cell cycle arrest, should be discussed more thoroughly.
#
# 3. The kinase regulation section contains some inaccuracies:
#    - AMPK generally activates SIRT1 by increasing NAD⁺ levels, not directly inhibiting it.
#    - The suggestion that AMPK phosphorylates PARP1 to enhance DNA repair needs clarification or citation, as this is not a widely recognized function.
#
# 4. The post-translational modification module effectively highlights several interactions, but the description of SUMOylation effects lacks specificity regarding its impact on cancer-related pathways.
#
# 5. The chromatin remodeling section accurately describes SIRT1 and PARP1 functions but misses the complexity of BRCA1 interactions beyond TP53 cooperation, such as its critical role in homologous recombination repair.
#
# 6. The transcriptional feedback loops are well-described but could benefit from more specificity, such as the contexts in which these loops are activated (e.g., stress response, cell cycle stages).
#
# 7. The circadian and metabolic integration section outlines key interactions but lacks discussion on how circadian disruption might contribute to cancer progression.
#
# "advice": "Provide more detailed context for each protein interaction, especially regarding their implications in cancer. Clarify any ambiguous or incorrect statements by cross-referencing current literature. Consider including relevant pathways or mechanisms where these proteins play a role to better illustrate their impact on cancer biology.",
# "causal_relationship_advice_graph": "
#  - SIRT1 inhibits TP53 deacetylation : 'SIRT1 deacetylates TP53, modulating its transcriptional activity and cell-fate decisions.'
#  - PARP1 ADP-ribosylates TP53 upon DNA damage : 'PARP1 ADP-ribosylates TP53, influencing its response to DNA damage.'
#  - AMPK activates SIRT1 via NAD⁺ modulation : 'AMPK generally activates SIRT1 by increasing NAD⁺ levels.'
#  - MDM2 ubiquitinates TP53 for degradation : 'MDM2 ubiquitinates TP53, leading to its proteasomal turnover.'
#  - BRCA1 interacts with TP53 to promote DNA repair : 'BRCA1 and TP53 cooperation promotes transcription of homologous-recombination genes.'
#  - CLOCK-BMAL1 complex regulates NAMPT expression : 'CLOCK and BMAL1 drive oscillatory NAD⁺ synthesis through NAMPT.'
#  - SIRT1 deacetylates E2F1 to regulate cell cycle : 'SIRT1 deacetylation of E2F1 modulates cell-cycle entry.'
# "

# %%
# Step 6: Query the LLM with the gene set, summary, and knowledge graph
knowledge_graph_prompt = KNOWLEDGE_GRAPH_TEMPLATE.format(
    statements = knowledge_graph)

prompt = PROMPT_TEMPLATE.format(
    geneset=kg_query_string,
    gene_set_summary = GENE_SET_SUMMARY,
    knowledge_graph=knowledge_graph_prompt
)

analysis_with_kg = query_llm(prompt)
print(analysis_with_kg)
# Out:
# ## Genes
# TP53, SIRT1, PARP1, NAMPT, NMNAT1, PKC, JNK, AMPK, PRKDC, MDM2, SUMO1, TIP60, MOF, XRCC1, POLB, LIG3, BRCA1, E2F1, MYC, RELA, CLOCK, BMAL1, PER2
#
# ## Critique:
# The provided summary offers a broad overview of the interactions among these genes and proteins within the context of cancer biology, focusing on NAD⁺ regulation, post-translational modifications, chromatin remodeling, transcriptional feedback loops, and circadian/metabolic integration. However, there are several points that could be clarified, expanded, or corrected:
#
# 1. **SIRT1 ↔ PARP1 Competition**: While SIRT1 and PARP1 both utilize NAD⁺, the summary could be clearer about the specific contexts in which their activities are antagonistic. Moreover, the influence of PKC on NMNAT1 and its impact on NAD⁺ availability could be further detailed.
#
# 2. **TP53 Integration**: The role of ADP-ribosylation by PARP1 and deacetylation by SIRT1 on TP53 is correctly noted, but the downstream effects on specific TP53 target genes and cellular outcomes (like apoptosis or cell-cycle arrest) could be further elaborated.
#
# 3. **Post-Translational Modifications**: The roles of JNK, AMPK, and DNA-PK are mentioned, but the summary could benefit from more specific information about the contexts in which these kinases exert their effects and how they are regulated themselves.
#
# 4. **Ubiquitin/SUMO Crosstalk**: The interplay between ubiquitination by MDM2 and SUMOylation needs a deeper exploration to understand their precise impact on protein stability and function, particularly for SIRT1 and PARP1.
#
# 5. **Chromatin Remodeling & DNA Repair**: The description of SIRT1 and PARP1 roles in chromatin remodeling could be expanded to encompass their broader impact on gene expression regulation and DNA repair pathways, such as homologous recombination vs. non-homologous end joining.
#
# 6. **Transcriptional Feedback Loops**: The interactions between TP53, MDM2, E2F1, c-MYC, and NF-κB are complex. A clearer description of the feedback mechanisms and their impact on cell fate decisions is needed.
#
# 7. **Circadian & Metabolic Integration**: While the role of CLOCK, BMAL1, and SIRT1 in circadian rhythms is mentioned, further details on how these interactions influence cancer metabolism specifically could be useful.
#
# "advice": "Ensure detailed descriptions of the molecular mechanisms, including specific contexts and conditions under which interactions occur. Explore downstream consequences of interactions on cellular processes and how these contribute to cancer pathogenesis.",
# "causal_relationship_advice_graph": "
#  - act(p(HGNC:PARP1)) directlyIncreases act(p(HGNC:TP53)) : Evidence indicates PARP1-mediated ADP-ribosylation of TP53 enhances its activity in response to DNA damage.
#  - act(p(HGNC:SIRT1)) directlyDecreases act(p(HGNC:TP53)) : SIRT1 deacetylates TP53, modulating its transcriptional activity.
#  - act(p(HGNC:MDM2)) directlyDecreases act(p(HGNC:TP53)) : MDM2 ubiquitinates TP53, targeting it for proteasomal degradation.
#  - act(p(HGNC:AMPK)) directlyDecreases act(p(HGNC:SIRT1)) : AMPK phosphorylates SIRT1, resulting in its inhibition under certain metabolic conditions.
#  - act(p(HGNC:JNK)) directlyIncreases act(p(HGNC:SIRT1)) : JNK activation leads to phosphorylation and activation of SIRT1.
#  - act(p(HGNC:PRKDC)) directlyIncreases act(p(HGNC:TP53)) : DNA-PK phosphorylates TP53, stabilizing and activating it for DNA repair processes.
#  - complex(p(HGNC:BRCA1), p(HGNC:TP53)) directlyIncreases bp(GO:0000724) : BRCA1 and TP53 interaction promotes transcriptional regulation of homologous recombination repair genes.
#  - act(p(HGNC:SIRT1)) directlyDecreases act(p(HGNC:RELA)) : SIRT1 deacetylates RELA/p65, reducing its transcriptional activity on inflammatory genes.
#  - complex(p(HGNC:CLOCK), p(HGNC:BMAL1)) directlyIncreases act(p(HGNC:NAMPT)) : CLOCK-BMAL1 complex induces NAMPT expression, influencing NAD⁺ biosynthesis.
# "
# }

# %% [markdown]
# ## Download the Knowledge Graph created using the texttoknowledgegraph tool on Cyweb and saved to NDEx

# %%
NEW_KG_UUID = "1a811f64-4b97-11f0-a218-005056ae3c32"   
new_cx2 = ndex_client.get_network_as_cx2_stream(NEW_KG_UUID).json()
with open("new_kg.cx2", "w") as f: json.dump(new_cx2, f)

# %%
# Step 11: Merge base and new networks
from ndex2.cx2 import RawCX2NetworkFactory
from textToKnowledgeGraph.convert_to_cx2 import add_style_to_network

# Creating an instance of RawCX2NetworkFactory
cx2_factory = RawCX2NetworkFactory()
base_net = cx2_factory.get_cx2network(base_cx2)
new_net  = cx2_factory.get_cx2network(new_cx2)

def merge_cx2(cx2_graphs):
    merged_graph = CX2Network()
    node_map = {}  # Maps (node_name, node_type) to node ID in merged graph
    
    # First, merge all nodes
    for graph in cx2_graphs:
        for node_id, node in graph.get_nodes().items():  # Changed to .items() based on docs
            # Create a tuple of node attributes that define uniqueness
            node_data = node["v"]
            node_name = node_data.get('name', '')
            
            if node_name not in node_map:
                # Create new node using add_node() as documented
                new_node_id = merged_graph.add_node(attributes=node_data)
                node_map[node_name] = new_node_id
    
    # Then, merge all edges
    for graph in cx2_graphs:
        for edge_id, edge_data in graph.get_edges().items():  
            # Get source and target directly from edge data
            source_id = edge_data.get('s')  
            target_id = edge_data.get('t') 
            
            # Get source and target nodes
            source_node = graph.get_node(source_id)
            source_name = source_node["v"]["name"]
            target_node = graph.get_node(target_id)
            target_name = target_node["v"]["name"]
            
            merged_source = node_map[source_name]
            merged_target = node_map[target_name]
            
            # Create edge using add_edge() as documented
            merged_graph.add_edge(source=merged_source, 
                                target=merged_target, 
                                attributes=edge_data["v"])
    
    return merged_graph


cx2_graphs = [base_net, new_net]
merged_network = merge_cx2(cx2_graphs)

# Apply style to the merged network
add_style_to_network(
    cx2_network=merged_network,
    style_path="/Users/favourjames/Downloads/llm-text-to-knowledge-graph/textToKnowledgeGraph/cx_style.json"   
)

merged_network.set_name("Merged Network of Base and New KGs")

# Upload the merged network to NDEx
merged_uuid = ndex_client.save_new_cx2_network(merged_network.to_cx2())

print("Merged network UUID:", merged_uuid)
# Out:
# INFO: [2025-06-18 16:52:24] textToKnowledgeGraph.convert_to_cx2 - Setting visual style properties
# Merged network UUID: https://www.ndexbio.org/v3/networks/3b99c216-4c5c-11f0-a218-005056ae3c32

# %% [markdown]
# ## LLM Query #3 — With Merged BEL Context

# %%
# Step 12: Critique with merged graph context
merged_uuid = "3b99c216-4c5c-11f0-a218-005056ae3c32"
sub3_cx2 = ndex2.create_nice_cx_from_raw_cx(ndex_client.get_neighborhood(merged_uuid, kg_query_string, search_depth=1))

knowledge_graph = ""
for edge_id, edge_obj in sub3_cx2.get_edges():
    knowledge_graph += sub3_cx2.get_edge_attribute_value(edge_obj, "bel_expression")
    knowledge_graph += "\n"

print("NDEx query done — BEL context prepared")

prompt3 = PROMPT_TEMPLATE.format(
    geneset=" ".join(kg_query_string),
    gene_set_summary=GENE_SET_SUMMARY,
    knowledge_graph=KNOWLEDGE_GRAPH_TEMPLATE.format(statements=knowledge_graph)
)

analysis_with_merged_kg = query_llm(prompt)
print(analysis_with_merged_kg)
# Out:
# NDEx query done — BEL context prepared
# INFO: [2025-06-18 16:57:48] httpx - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ## Genes
# TP53, SIRT1, PARP1, NAMPT, NMNAT1, PKC, JNK, AMPK, PRKDC, MDM2, SUMO1, TIP60, MOF, XRCC1, POLB, LIG3, BRCA1, E2F1, MYC, RELA, CLOCK, BMAL1, PER2
#
# ## Critique:
# The summary provides a broad overview of the interactions between the gene set, focusing on NAD⁺ metabolism, TP53 regulation, post-translational modifications, chromatin remodeling, transcriptional feedback loops, and circadian/metabolic integration. While the summary captures many critical interactions, there are areas where more detail or clarification would enhance understanding:
#
# 1. SIRT1 and PARP1 Competition: The summary correctly identifies SIRT1 and PARP1 as competing for NAD⁺. However, it could be more precise in describing the outcomes of this competition on cellular processes, such as DNA repair and apoptosis.
#
# 2. TP53 Integration: The statement that PARP1 ADP-ribosylates TP53 upon DNA damage is correct, but it could benefit from more detail on how this modification affects TP53's role in DNA repair and apoptosis.
#
# 3. Post-Translational Modification Module: The description of kinase regulation is largely accurate, but it might be beneficial to expand on the implications of these post-translational modifications in cancer biology, such as how they influence cell survival or death.
#
# 4. Chromatin Remodeling & DNA Repair Hub: The mention of TIP60 and MOF in directing DSB repair pathway choice is accurate, but more context on how these processes differ in cancerous vs. non-cancerous cells would be beneficial.
#
# 5. Transcriptional Feedback Loops: The summary captures essential feedback loops but could elaborate on how dysregulation of these loops contributes to tumorigenesis.
#
# 6. Circadian & Metabolic Integration: The description of circadian regulation through CLOCK and BMAL1 is accurate. However, it could be expanded to include how circadian disruption may contribute to cancer development.
#
# Advice to improve the summary:
# - Include more specific examples of how these interactions are altered in cancer cells.
# - Provide additional context on the biological significance of these interactions, particularly in the context of cancer.
# - Highlight any potential therapeutic targets within these pathways for cancer treatment.
#
# "advice": "Provide more detailed explanations of the outcomes of interactions, particularly in the context of cancer biology. Include examples of how these pathways are altered in cancer and discuss potential therapeutic targets.",
# "causal_relationship_advice_graph": "
#  - p(HGNC:TP53) directlyIncreases a(HGNC:CDKN1A) : 'CDKN1A (p21) is a significant target of TP53, regulating cell cycle arrest.'
#  - act(p(HGNC:PRKDC)) increases act(p(HGNC:TP53)) : 'PRKDC (DNA-PK) is involved in TP53 phosphorylation, enhancing its stability and activity.'
#  - act(p(HGNC:MDM2)) directlyDecreases act(p(HGNC:TP53)) : 'MDM2 ubiquitinates TP53, targeting it for degradation and regulating its cellular levels.'
#  - p(HGNC:XRCC1) directlyDecreases act(p(HGNC:PARP1)) : 'XRCC1 interacts with PARP1 in base excision repair, modulating its activity.'
#  - complex(p(HGNC:E2F1), p(HGNC:TFDP1)) increases bp(GO:\"transcriptional stimulation\") : 'The E2F1/TFDP1 complex is crucial for driving cell cycle progression by activating transcription of necessary genes.'
# "
